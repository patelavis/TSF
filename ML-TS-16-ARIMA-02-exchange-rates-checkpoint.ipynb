# %%
import warnings
warnings.filterwarnings("ignore")

import itertools
import pandas as pd
import numpy as np

import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from dateutil.parser import parse

from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error

import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

plt.style.use('fivethirtyeight')

from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15, 5

# %%
location = r"E:\MYLEARN\2-ANALYTICS-DataScience\datasets\exchange.csv"

# %%
exchangeRatesSeries  = pd.read_csv(location, header=0, parse_dates=[0], index_col=0)

# %%
exchangeRatesSeries.head()
# Out:
#             GBP/USD Close
# Date
# 1998-12-31          88.67
# 1999-01-01          88.67
# 1999-01-04          85.60
# 1999-01-05          83.95
# 1999-01-06          86.96

# %%
# view basic stats information on data
exchangeRatesSeries.describe()
# Out:
#        GBP/USD Close
# count    5100.000000
# mean       89.732223
# std        63.037321
# min        17.040000
# 25%        45.965000
# 50%        73.315500
# 75%        94.187500
# max       250.280000

# %% [markdown]
# describe() shows a number of useful metrics including:
#
#     count — Number of records,
#     mean  — expected value,
#     std   — Standard deviation telling us dispersion of data around the mean,
#     min   — Minimum value in the set,
#     max   — Maximum value in the set along with a range of percentiles.
#
# Percentiles can help us understand probability distribution of our data.

# %% [markdown]
# # Data Exploration

# %%
# plot the time series data

exchangeRatesSeries.plot(color='green');

# %% [markdown]
# Histograms can help us understand distribution of data which in return helps us in forecasting a variable:

# %%
exchangeRatesSeries.hist();

# %%
# Function that calls ARIMA model to fit and forecast the data
def StartARIMAForecasting(Actual, P, D, Q):
    
    model     = ARIMA(Actual, order=(P, D, Q))
    
    model_fit = model.fit(disp=0)
    
    prediction = model_fit.forecast()[0]
    
    return prediction

# %%
# creating data
ExchangeRates = [[1],
                 [1.5],
                 [2],
                 [4],
                 [6],
                 [8],
                 [16],
                 [1]]

# %%
# predict next value
predicted = StartARIMAForecasting(ExchangeRates, 1,1,0)

# display the value
print('Predicted=%f' % (predicted))
# Out:
# Predicted=15.219305

# %%
# Size of exchange rates
NumberOfElements = len(exchangeRatesSeries)
NumberOfElements
# Out:
# 5100

# %%
# Use 70% of data as training, rest 30% to Test model
TrainingSize = int(NumberOfElements * 0.7)

TrainingData = exchangeRatesSeries[0:TrainingSize].values

TestData     = exchangeRatesSeries[TrainingSize:NumberOfElements].values

# %%
type(TestData)
# Out:
# numpy.ndarray

# %%
# new arrays to store actual and predictions
Actual      = [x for x in TrainingData]
Predictions = list()

# in a for loop, predict values using ARIMA model
for timepoint in range(len(TestData)):
    ActualValue =  TestData[timepoint]
    
    # forcast value
    Prediction = StartARIMAForecasting(Actual, 3, 1, 0)    
    #print('Actual=%f, Predicted=%f' % (ActualValue, Prediction))
    
    # add it in the list
    Predictions.append(Prediction)
    Actual.append(ActualValue)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-f92b3abe1e8b> in <module>()
#      16
#      17 # Print MSE to see how good the model is
# ---> 18 Error = metrics.mean_squared_error (TestData, Predictions)
#      19 print('Test Mean Squared Error (smaller the better fit): %.3f' % Error)
#      20
#
# NameError: name 'metrics' is not defined

# %%
# Print MSE to see how good the model is
Error = mean_squared_error (TestData, Predictions)
print('Test Mean Squared Error (smaller the better fit): %.3f' % Error)

# plot
plt.plot(TestData)
plt.plot(Predictions, color='red')
# Out:
# Test Mean Squared Error (smaller the better fit): 1.551
